# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Test sur une image en couleur

# %%
from PIL import Image
import numpy as np
image_path = 'C:/Users/user/ima.png'
image = Image.open(image_path)
image_gray = image.convert('L')
image_array = np.array(image_gray)
image_2d = image_array.reshape(image_gray.size[1], image_gray.size[0])
print("Reshaped Image Shape:", reshaped_image.shape)
# Out:
# Reshaped Image Shape: (198, 255)

# %%
import matplotlib.pyplot as plt
plt.imshow(image_2d, cmap='gray')
plt.axis('off')
plt.show()

# %%
from PIL import Image
import numpy as np
image_path = 'C:/Users/user/ima.png'
image = Image.open(image_path)
image_rgb = image.convert('RGB')
image_array = np.array(image_rgb)
image_2d = image_array.reshape(image_rgb.size[1], image_rgb.size[0], 3)
import matplotlib.pyplot as plt
plt.imshow(image_2d)
plt.axis('off')
plt.show()

# %% [markdown]
# # Test sur une image noir et blan a 3-D

# %%
from PIL import Image
import numpy as np
image_path = 'C:/Users/user/image.png'
image = Image.open(image_path)
image_gray = image.convert('L')
image_array = np.array(image_gray)
image_2d = image_array.reshape(image_gray.size[1], image_gray.size[0])
print("Reshaped Image Shape:", reshaped_image.shape)
# Out:
# Reshaped Image Shape: (198, 255)

# %%
import matplotlib.pyplot as plt
plt.imshow(image_2d, cmap='gray')
plt.axis('off')
plt.show()
